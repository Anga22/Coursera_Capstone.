# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# getting data from wiki link
# remove Not assigned elements
# change indices to new count.

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = requests.get(wiki)
wiki_raw = pd.read_html(wiki_page.content, header = 0)[0]
df = wiki_raw[wiki_raw.Borough != 'Not assigned']
df.reset_index(inplace = True)
df.head()
# Out:
#    index Postal Code           Borough  \
# 0      2         M3A        North York
# 1      3         M4A        North York
# 2      4         M5A  Downtown Toronto
# 3      5         M6A        North York
# 4      6         M7A  Downtown Toronto
#
#                                  Neighbourhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %% [markdown]
# Group data by costal code to deal with repititions

# %%
df.groupby(['Postal Code']).first()
# Out:
#              index      Borough  \
# Postal Code
# M1B              9  Scarborough
# M1C             18  Scarborough
# M1E             27  Scarborough
# M1G             36  Scarborough
# M1H             45  Scarborough
# ...            ...          ...
# M9N             98         York
# M9P            107    Etobicoke
# M9R            116    Etobicoke
# M9V            143    Etobicoke
# M9W            152    Etobicoke
#
#                                                  Neighbourhood
# Postal Code
# M1B                                             Malvern, Rouge
# M1C                     Rouge Hill, Port Union, Highland Creek
# M1E                          Guildwood, Morningside, West Hill
# M1G                                                     Woburn
# M1H                                                  Cedarbrae
# ...                                                        ...
# M9N                                                     Weston
# ...

# %% [markdown]
# Checked unique elements

# %%
len(df['Postal Code'].unique())
# Out:
# 103

# %% [markdown]
# displayed only new index count

# %%
df[df['Borough'] == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [index, Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# used shape to get number of rows

# %%
df.shape
# Out:
# (103, 4)

# %% [markdown]
# # part 2

# %% [markdown]
# I decided to use link to save time

# %% [markdown]
# get data from link
#
# create dataframe
#
# get top 5 rows from data

# %%
url = 'http://cocl.us/Geospatial_data'
df_geo = pd.read_csv(url)
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Join the data

# %%
df = df.join(df_geo.set_index('Postal Code'), on='Postal Code')
df
# Out:
#      index Postal Code           Borough  \
# 0        2         M3A        North York
# 1        3         M4A        North York
# 2        4         M5A  Downtown Toronto
# 3        5         M6A        North York
# 4        6         M7A  Downtown Toronto
# ..     ...         ...               ...
# 98     160         M8X         Etobicoke
# 99     165         M4Y  Downtown Toronto
# 100    168         M7Y      East Toronto
# 101    169         M8Y         Etobicoke
# 102    178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ...

# %% [markdown]
# Drop old index from first data frame

# %%
df = df.reset_index()
df.drop(['index'], axis = 'columns', inplace = True)
df.head()
# Out:
#    level_0 Postal Code           Borough  \
# 0        0         M3A        North York
# 1        1         M4A        North York
# 2        2         M5A  Downtown Toronto
# 3        3         M6A        North York
# 4        4         M7A  Downtown Toronto
#
#                                  Neighbourhood   Latitude  Longitude
# 0                                    Parkwoods  43.753259 -79.329656
# 1                             Victoria Village  43.725882 -79.315572
# 2                    Regent Park, Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park, Ontario Provincial Government  43.662301 -79.389494

# %%
df = df.rename(index = {'level_0' : 'index'})
df.index.name = 'index'
df.head()
# Out:
#        level_0 Postal Code           Borough  \
# index
# 0            0         M3A        North York
# 1            1         M4A        North York
# 2            2         M5A  Downtown Toronto
# 3            3         M6A        North York
# 4            4         M7A  Downtown Toronto
#
#                                      Neighbourhood   Latitude  Longitude
# index
# 0                                        Parkwoods  43.753259 -79.329656
# 1                                 Victoria Village  43.725882 -79.315572
# 2                        Regent Park, Harbourfront  43.654260 -79.360636
# 3                 Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4      Queen's Park, Ontario Provincial Government  43.662301 -79.389494
